# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fis=pd.read_csv('Fish.csv')

# %%
print(fis)
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
fis
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
fis.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
fis.tail()
# Out:
#     Species  Weight  Length1  Length2  Length3  Height   Width
# 154   Smelt    12.2     11.5     12.2     13.4  2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5  2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8  2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2  2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2  2.9322  1.8792

# %%
fis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
fis.shape
# Out:
# (159, 7)

# %%
fis.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
fis['Species'].nunique()
# Out:
# 7

# %%
fis['Species'].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
fis['Species'].value_counts()
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
fis['Species'].value_counts().tail()
# Out:
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
fis['Species'].value_counts(sort=True,ascending=True)
# Out:
# Whitefish     6
# Parkki       11
# Smelt        14
# Pike         17
# Roach        20
# Bream        35
# Perch        56
# Name: Species, dtype: int64

# %%
fi=fis.sample(frac=0.7,axis=0)

# %%
fi.head()
# Out:
#        Species  Weight  Length1  Length2  Length3   Height   Width
# 113      Perch   700.0     34.0     36.0     38.3  10.6091  6.7408
# 120      Perch   900.0     37.0     40.0     42.5  11.7300  7.2250
# 82       Perch   110.0     19.0     21.0     22.5   5.6925  3.5550
# 103      Perch   260.0     25.4     27.5     28.9   7.1672  4.3350
# 60   Whitefish  1000.0     37.3     40.0     43.5  12.3540  6.5250

# %%
fis.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
fis['Weight'].max()
# Out:
# 1650.0

# %%
fis.iloc[fis['Weight'].idxmax()]
# Out:
# Species      Pike
# Weight     1650.0
# Length1      59.0
# Length2      63.4
# Length3      68.0
# Height     10.812
# Width        7.48
# Name: 144, dtype: object

# %% [markdown]
# find the Species , Weight, Width of the shortest fish

# %%
fis.iloc[fis['Height'].idxmin()][['Species','Width','Weight']]
# Out:
# Species     Smelt
# Width      1.1484
# Weight        7.0
# Name: 147, dtype: object

# %%
fis['Height'].idxmin()
# Out:
# 147

# %% [markdown]
# # univariate analysis

# %%
fis[fis['Width']<2].count()
# Out:
# Species    15
# Weight     15
# Length1    15
# Length2    15
# Length3    15
# Height     15
# Width      15
# dtype: int64

# %%
import seaborn as sns

# %%
sns.displot(data=fis['Species'])

# %%
sns.displot(data=fis['Weight'])

# %%
sns.boxplot(data = fis,x = 'Weight')
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
fis[fis['Weight']>1300]
# Out:
#     Species  Weight  Length1  Length2  Length3  Height  Width
# 142    Pike  1600.0     56.0     60.0     64.0   9.600  6.144
# 143    Pike  1550.0     56.0     60.0     64.0   9.600  6.144
# 144    Pike  1650.0     59.0     63.4     68.0  10.812  7.480

# %%
sns.displot(data=fis['Length1'])

# %%
sns.displot(data=fis['Length2'])

# %%
sns.displot()

# %%
fis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %% [markdown]
# # outlier

# %% [markdown]
# ### NORMAL DISTRIBUTION

# %%
sns.displot(data=fis['Weight'],kind="kde")

# %%
mean_Weight=np.mean(fis['Weight'])

# %%
print(mean_Weight)
# Out:
# 398.3264150943396

# %% [markdown]
# # REMOVE OUTLIER

# %%
#Removing Outlier using 2nd std Technique

#columns=['Weight','Length1','Length2','Length3','Height','Width']

#for column in columns:
   # lower_bound=np.mean(fis[column]) - (2* np.std(fis[column]))
    #upper_bound=np.mean(fis[column]) + (2*np.std(fis[column]))
    #print(lower_bound,upper_bound)
    #fis.drop(fis[fis[column]>upper_bound].index,inplace=True)
    #fis.drop(fis[fis[column]<lower_bound].index,inplace=True)

# %%
fis.shape
# Out:
# (159, 7)

# %% [markdown]
# ### INTER QUARTILE RANGE

# %%
Weight_percentile = np.percentile(fis['Weight'],25)

# %%
Weight_percentile
# Out:
# 120.0

# %%
Weight_percentile = np.percentile(fis['Weight'],75)

# %%
Weight_percentile
# Out:
# 650.0

# %%
#Removing Outliers Using  IQR

columns = ['Weight','Length1','Length2','Length3','Height','Width']

for column in columns:
    iqr = np.percentile(fis[column],75) -  np.percentile(fis[column],25)
    upper_limit =  np.percentile(fis[column],75) + (1.5 * (iqr))
    lower_limit =  np.percentile(fis[column],25) - (1.5 * (iqr))
    print(iqr, upper_limit, lower_limit)
    fis.drop(fis[fis[column]>upper_limit].index,inplace = True)
    fis.drop(fis[fis[column]<lower_limit].index,inplace = True)
# Out:
# 530.0 1445.0 -675.0
# 13.125 51.8125 -0.6875
# 14.0 56.0 0.0
# 16.39999999999999 63.94999999999998 -1.6499999999999844
# 6.452350000000001 22.057825 -3.7515750000000008
# 2.0096000000000007 8.387600000000003 0.34919999999999884

# %%
fis.shape
# Out:
# (155, 7)

# %%
fish_check = fis.drop('Species',axis = 1)

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
fis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  155 non-null    object
#  1   Weight   155 non-null    float64
#  2   Length1  155 non-null    float64
#  3   Length2  155 non-null    float64
#  4   Length3  155 non-null    float64
#  5   Height   155 non-null    float64
#  6   Width    155 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.8+ KB

# %%
sns.scatterplot(x = 'Height',y = 'Weight',data = fis)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %% [markdown]
# obs: ....

# %%
sns.scatterplot(x = 'Height',y = 'Weight',data = fis,hue = 'Species')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %% [markdown]
# obs:....

# %%
fis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  155 non-null    object
#  1   Weight   155 non-null    float64
#  2   Length1  155 non-null    float64
#  3   Length2  155 non-null    float64
#  4   Length3  155 non-null    float64
#  5   Height   155 non-null    float64
#  6   Width    155 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.8+ KB

# %%
plt.figure(figsize = (12,10))
sns.boxplot(x = 'Species',y = 'Length1',data = fis)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Length1'>

# %% [markdown]
# obs:..

# %%
sns.pairplot(data = fis,hue = 'Species',palette = 'viridis')

# %% [markdown]
# obs:

# %%
fis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  155 non-null    object
#  1   Weight   155 non-null    float64
#  2   Length1  155 non-null    float64
#  3   Length2  155 non-null    float64
#  4   Length3  155 non-null    float64
#  5   Height   155 non-null    float64
#  6   Width    155 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.8+ KB

# %% [markdown]
# # DATA  TYPE CONVERTION

# %%
fis['Species'] = fis['Species'].astype('category')

# %%
fis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  155 non-null    category
#  1   Weight   155 non-null    float64
#  2   Length1  155 non-null    float64
#  3   Length2  155 non-null    float64
#  4   Length3  155 non-null    float64
#  5   Height   155 non-null    float64
#  6   Width    155 non-null    float64
# dtypes: category(1), float64(6)
# memory usage: 13.0 KB

# %% [markdown]
# # ONE HOT ENCODING

# %%
fis.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
fish_final = pd.get_dummies(fis)

# %%
fish_final.tail(10)
# Out:
#      Weight  Length1  Length2  Length3  Height   Width  Species_Bream  \
# 149     9.8     10.7     11.2     12.4  2.0832  1.2772              0
# 150     8.7     10.8     11.3     12.6  1.9782  1.2852              0
# 151    10.0     11.3     11.8     13.1  2.2139  1.2838              0
# 152     9.9     11.3     11.8     13.1  2.2139  1.1659              0
# 153     9.8     11.4     12.0     13.2  2.2044  1.1484              0
# 154    12.2     11.5     12.2     13.4  2.0904  1.3936              0
# 155    13.4     11.7     12.4     13.5  2.4300  1.2690              0
# 156    12.2     12.1     13.0     13.8  2.2770  1.2558              0
# 157    19.7     13.2     14.3     15.2  2.8728  2.0672              0
# 158    19.9     13.8     15.0     16.2  2.9322  1.8792              0
#
#      Species_Parkki  Species_Perch  Species_Pike  Species_Roach  \
# 149               0              0             0              0
# 150               0              0             0              0
# ...

# %%
np.std(fish_final)
# Out:
# Weight               311.675081
# Length1                8.869116
# Length2                9.525093
# Length3               10.434619
# Height                 4.322064
# Width                  1.658917
# Species_Bream          0.418112
# Species_Parkki         0.256771
# Species_Perch          0.480374
# Species_Pike           0.277194
# Species_Roach          0.335236
# Species_Smelt          0.286643
# Species_Whitefish      0.192902
# dtype: float64

# %% [markdown]
# # PREDICTIVE ANALYSIS

# %%
#Splitting the data
from sklearn.model_selection import train_test_split
features = [col for col in fish_final.columns if col != 'Weight']

X_train, X_test, y_train, y_test = train_test_split(fish_final[features], fish_final['Weight'], test_size=.2, random_state=22)
X_train.shape, X_test.shape
# Out:
# ((124, 12), (31, 12))

# %%
fish_final.columns
# Out:
# Index(['Weight', 'Length1', 'Length2', 'Length3', 'Height', 'Width',
#        'Species_Bream', 'Species_Parkki', 'Species_Perch', 'Species_Pike',
#        'Species_Roach', 'Species_Smelt', 'Species_Whitefish'],
#       dtype='object')

# %%
features
# Out:
# ['Length1',
#  'Length2',
#  'Length3',
#  'Height',
#  'Width',
#  'Species_Bream',
#  'Species_Parkki',
#  'Species_Perch',
#  'Species_Pike',
#  'Species_Roach',
#  'Species_Smelt',
#  'Species_Whitefish']

# %%
X_train
# Out:
#      Length1  Length2  Length3   Height   Width  Species_Bream  \
# 88      20.0     22.0     23.5   6.1100  3.5250              0
# 155     11.7     12.4     13.5   2.4300  1.2690              0
# 151     11.3     11.8     13.1   2.2139  1.2838              0
# 139     44.8     48.0     51.2   7.6800  5.3760              0
# 98      22.6     24.6     26.2   6.7334  4.1658              0
# ..       ...      ...      ...      ...     ...            ...
# 102     25.2     27.3     28.7   8.3230  5.1373              0
# 100     23.5     25.6     27.0   6.5610  4.2390              0
# 44      20.5     22.0     24.3   6.6339  3.5478              0
# 132     35.5     38.0     40.5   7.2900  4.5765              0
# 117     36.5     39.0     41.4  11.1366  6.0030              0
#
#      Species_Parkki  Species_Perch  Species_Pike  Species_Roach  \
# 88                0              1             0              0
# 155               0              0             0              0
# ...

# %%
#Normalising the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test= sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.63894028, -0.60730356, -0.67865909, ..., -0.35675303,
#         -0.31200182, -0.22549381],
#        [-1.61287   , -1.65579399, -1.66998583, ..., -0.35675303,
#          3.20510956, -0.22549381],
#        [-1.65980637, -1.72132465, -1.7096389 , ..., -0.35675303,
#          3.20510956, -0.22549381],
#        ...,
#        [-0.58026982, -0.60730356, -0.59935295, ...,  2.80305955,
#         -0.31200182, -0.22549381],
#        [ 1.17984412,  1.1401805 ,  1.00659637, ..., -0.35675303,
#         -0.31200182, -0.22549381],
#        [ 1.29718504,  1.24939826,  1.09581577, ..., -0.35675303,
#         -0.31200182, -0.22549381]])

# %%
from sklearn.linear_model import LinearRegression
linearregression = LinearRegression()                                    
linearregression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linearregression.coef_
# Out:
# array([ 111.64568992,  140.40416825, -143.2089241 ,  220.07819159,
#          80.31340852,  -67.00105902,  -15.56570562,   12.78521905,
#           2.02758382,   -2.75264653,   91.22085661,    1.83706248])

# %%
linearregression.intercept_
# Out:
# 373.3072580645162

# %%
y_predict = linearregression.predict(X_test)

# %%
y_predict
# Out:
# array([-321.82588493,  485.57409533,  867.81096045,  596.52293511,
#        -157.74891741,   97.74997589,  224.61009866,  208.98247217,
#         141.6361004 ,  137.03702319,  147.95974571,  526.8339505 ,
#          -1.2802572 ,  476.90835532,   91.4066782 ,  902.29643219,
#         354.86792113,   16.32567818,  780.87984683,  870.95698651,
#         116.27112486,  361.23678739,  144.13147445,  212.89917974,
#         644.56004453,  719.39474921,   86.35417154,   99.76309853,
#         624.64791246,  216.36547468,  845.01740287])

# %%
pred = linearregression.predict(X_test)
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# Mean Absolute Error
print("\nMean Absolute Error:", mean_absolute_error(y_test, pred))
# RMSE
print("\nRMSE:", mean_squared_error(y_test, pred)**0.5)
# R2 Squared:
print("\nR2 Squared - Score:", r2_score(y_test, pred))
# Training Score
print("\nTraining Score:", linearregression.score(X_train, y_train))
# Testing score
print("\nTesting score:",linearregression.score(X_test, y_test))
# Out:
# Mean Absolute Error: 59.367045822460135
#
# RMSE: 89.72705315032657
#
# R2 Squared - Score: 0.9214457654484625
#
# Training Score: 0.9534733205145658
#
# Testing score: 0.9214457654484625

# %%
X_test
# Out:
# array([[-2.1057019 , -2.09266501, -2.13590939, -1.61925977, -1.79929402,
#         -0.55250625, -0.26261287,  1.25830574, -0.26261287, -0.35675303,
#         -0.31200182, -0.22549381],
#        [ 0.47579854,  0.45210865,  0.46136666,  0.0996088 ,  0.5727084 ,
#         -0.55250625, -0.26261287, -0.79471941, -0.26261287,  2.80305955,
#         -0.31200182, -0.22549381],
#        [ 1.12117365,  1.19478938,  1.36347399,  2.09331451,  1.14440485,
#          1.80993427, -0.26261287, -0.79471941, -0.26261287, -0.35675303,
#         -0.31200182, -0.22549381],
#        [ 2.08336927,  2.01392253,  1.81948429, -0.29508054,  0.28124116,
#         -0.55250625, -0.26261287, -0.79471941,  3.80788655, -0.35675303,
#         -0.31200182, -0.22549381],
#        [-1.47206088, -1.47012381, -1.40232761, -1.14479329, -1.28246552,
#         -0.55250625, -0.26261287, -0.79471941, -0.26261287,  2.80305955,
#         -0.31200182, -0.22549381],
# ...

# %%
linearregression.predict([[ 1.35585551,  1.35861601,  1.20486172,  0.62298598,  1.6965099 ,
        -0.55250625, -0.26261287,  1.25830574, -0.26261287, -0.35675303,
        -0.31200182, -0.22549381]])
# Out:
# array([845.01740159])
